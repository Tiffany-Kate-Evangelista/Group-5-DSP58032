# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 4))
plt.title('Phase Shift')
plt.plot(N, np.sin(N), label=r'$\sin \theta$')
plt.plot(N, np.sin(N + np.pi / 4), label=r'$\sin \theta + \frac{\pi}{4}$')

plt.legend()
plt.grid()
plt.show()

# %%
N = np.linspace(0, 2 * np.pi, 100)

plt.figure(figsize=(10, 4))
plt.title('Phase Shift')

plt.plot(N, np.sin(N), label=r'$\sin \theta$', color='red')
plt.plot(N, np.sin(N + np.pi / 4), label=r'$\sin \theta + \frac{\pi}{4}$', color='green')

plt.legend()
plt.grid()
plt.show()

# %%
N = np.linspace(-2*np.pi, 2*np.pi, 100)

plt.figure(figsize=(10, 4))
plt.plot (N, euler(N).real, label='real')
plt.plot (N, euler(N).imag, label='imaginary')

plt.legend()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 N = np.linspace(-2*np.pi, 2*np.pi, 100)
#       3 plt.figure(figsize=(10, 4))
# ----> 4 plt.plot (N, euler(N).real, label='real')
#       5 plt.plot (N, euler(N).imag, label='imaginary')
#       7 plt.legend()
#
# NameError: name 'euler' is not defined

# %%
N = np.linspace(-2*np.pi, 2*np.pi, 100)
euler_N= np.exp(1j*N)

plt.figure(figsize=(10, 4))
plt.plot (N, euler_N.real, label='real', color='red')
plt.plot (N, euler_N.imag, label='imaginary', color='green')

plt.legend()
plt.grid()
plt.title("Euler's Formula: Real and Imaginary Parts")
plt.show()
